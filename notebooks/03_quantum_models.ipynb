# %% [markdown]
# # Quantum-Enhanced Machine Learning Models
#
# This notebook explores quantum computing approaches for threat intelligence classification.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys

# Set project root and add utils to path
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root / 'utils'))

from quantum_utils import create_quantum_feature_map, quantum_kernel_similarity

# Check quantum libraries
try:
    import qiskit
    print(f"✅ Qiskit version: {qiskit.__version__}")
except ImportError:
    print("⚠️ Qiskit not installed. Install with: pip install qiskit")

try:
    import pennylane as qml
    print(f"✅ PennyLane version: {qml.__version__}")
except ImportError:
    print("⚠️ PennyLane not installed. Install with: pip install pennylane")
# Out:
# ✅ Qiskit version: 2.3.0
# ⚠️ PennyLane not installed. Install with: pip install pennylane

# %% [markdown]
# ## Quantum Models (Placeholder)
#
# This section will implement quantum-enhanced models once the quantum utilities are fully developed.
